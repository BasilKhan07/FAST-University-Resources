# %% [markdown]
# # Deep Learning with Keras

# %% [markdown]
# To use Keras, will need to have the TensorFlow package installed. See detailed instructions. https://www.tensorflow.org/install
#
# Once TensorFlow is installed, just import Keras via:

# %%
from tensorflow import keras # No need for installation on Google Colab

# %% [markdown]
# ### Input layers

# %%
# Import Input from keras.layers
from keras.layers import Input
# Create an input layer of shape 1
input_tensor = Input(shape=(1,))

# %% [markdown]
# https://keras.io/api/layers/core_layers/input/
#
# tf.keras.Input(
#     shape=None,
#     batch_size=None,
#     name=None,
#     dtype=None,
#     sparse=None,
#     tensor=None,
#     ragged=None,
#     type_spec=None,
#     **kwargs
# )
# Arguments
#
#
# *   shape: A shape tuple (integers), not including the batch size. For instance, shape=(32,) indicates that the expected input will be batches of 32-dimensional vectors. Elements of this tuple can be None; 'None' elements represent dimensions where the shape is not known.
# *   batch_size: optional static batch size (integer).
#
# * name: An optional name string for the layer. Should be unique in a model (do not reuse the same name twice). It will be autogenerated if it isn't provided.
# * dtype: The data type expected by the input, as a string (float32, float64, int32...)
# *  sparse: A boolean specifying whether the placeholder to be created is sparse. Only one of 'ragged' and 'sparse' can be True. Note that, if sparse is False, sparse tensors can still be passed into the input - they will be densified with a default value of 0.
# *  tensor: Optional existing tensor to wrap into the Input layer. If set, the layer will use the tf.TypeSpec of this tensor rather than creating a new placeholder tensor.
# * ragged: A boolean specifying whether the placeholder to be created is ragged. Only one of 'ragged' and 'sparse' can be True. In this case, values of 'None' in the 'shape' argument represent ragged dimensions. For more information about RaggedTensors, see this guide.
# *   type_spec: A tf.TypeSpec object to create the input placeholder from. When provided, all other args except name must be None.
# * **kwargs: deprecated arguments support. Supports batch_shape and batch_input_shape.

# %% [markdown]
# ### Dense layers

# %% [markdown]
# https://keras.io/api/layers/core_layers/dense/
#
# units=10
# tf.keras.layers.Dense(
#     units,
#     activation=None,
#     use_bias=True,
#     kernel_initializer="glorot_uniform",
#     bias_initializer="zeros",
#     kernel_regularizer=None,
#     bias_regularizer=None,
#     activity_regularizer=None,
#     kernel_constraint=None,
#     bias_constraint=None,
# )
#
# Arguments
#
# * units: Positive integer, dimensionality of the output space.
# * activation: Activation function to use. If you don't specify anything, no activation is applied (ie. "linear" activation: a(x) = x).
# * use_bias: Boolean, whether the layer uses a bias vector.
# *  kernel_initializer: Initializer for the kernel weights matrix.
# * bias_initializer: Initializer for the bias vector.
# * kernel_regularizer: Regularizer function applied to the kernel weights matrix.
# * bias_regularizer: Regularizer function applied to the bias vector.
# * activity_regularizer: Regularizer function applied to the output of the layer (its "activation").
# * kernel_constraint: Constraint function applied to the kernel weights matrix.
# * bias_constraint: Constraint function applied to the bias vector.

# %%
# Load layers
from keras.layers import Input, Dense

# Input layer
input_tensor = Input(shape=(1,))

# Dense layer
output_layer = Dense(1)

# Connect the dense layer to the input_tensor
output_tensor = output_layer(input_tensor)

# %% [markdown]
# This network will take the input, apply a linear coefficient to it, and return the result.

# %% [markdown]
# The output layer allows your model to make predictions.

# %% [markdown]
# ### Build a model

# %%
# Input/dense/output layers
from keras.layers import Input, Dense
input_tensor = Input(shape=(1,),name='input')
output_tensor = Dense(1, name='dense1')(input_tensor)

# Build the model
from keras.models import Model
model = Model(input_tensor, output_tensor)

# %% [markdown]
# ### Compile a model

# %% [markdown]
# This finalizes your model, freezes all its settings, and prepares it to meet some data!

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy')

# %% [markdown]
# ### Visualize a model

# %%
# Import the plotting function
from keras.utils import plot_model
import matplotlib.pyplot as plt

# Summarize the model
model.summary()

# # Plot the model
plot_model(model, to_file='model.png')
# # Display the image
data = plt.imread('model.png')
plt.imshow(data)
plt.show()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 1)]               0
#
#  dense1 (Dense)              (None, 1)                 2
#
# =================================================================
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
print(model.get_weights())
# Out:
# [array([[0.9937645]], dtype=float32), array([0.], dtype=float32)]

# %% [markdown]
# # Sequential class
#
# tf.keras.Sequential(layers=None, name=None)
#
# Sequential groups a linear stack of layers into a tf.keras.Model.
#
# Sequential provides training and inference features on this model.
#
# Optionally, the first layer can receive an `input_shape` argument:

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(50, input_shape=(20, ), name='dense1'))
model.add(Dense(30, name='dense2'))
model.add(Dense(1, name='dense3'))
model.compile(optimizer='sgd', loss='mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense1 (Dense)              (None, 50)                1050
#
#  dense2 (Dense)              (None, 30)                1530
#
#  dense3 (Dense)              (None, 1)                 31
#
# =================================================================
# Total params: 2611 (10.20 KB)
# Trainable params: 2611 (10.20 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# For Multiple Observations

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(50, input_shape=(20, 25), name='dense1'))
model.add(Dense(30, name='dense2'))
model.add(Dense(1, name='dense3'))
model.compile('rmsprop', 'mse')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense1 (Dense)              (None, 20, 50)            1300
#
#  dense2 (Dense)              (None, 20, 30)            1530
#
#  dense3 (Dense)              (None, 20, 1)             31
#
# =================================================================
# Total params: 2861 (11.18 KB)
# Trainable params: 2861 (11.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Example on Heart Disease Dataset

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(50, input_shape=(2,), name='dense1'))
model.add(Dense(30, name='dense2'))
model.add(Dense(1, name='dense3'))
model.compile(optimizer='sgd', loss='binary_crossentropy')
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense1 (Dense)              (None, 50)                150
#
#  dense2 (Dense)              (None, 30)                1530
#
#  dense3 (Dense)              (None, 1)                 31
#
# =================================================================
# Total params: 1711 (6.68 KB)
# Trainable params: 1711 (6.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import pandas as pd

df = pd.read_csv('/content/heart_disease_dataset_UCI.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.shape
# Out:
# (303, 14)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df[['age','sex']], df['target'])

# %%
# Now fit the model
model.fit(X_train, y_train,
          epochs=1,
          batch_size=128,
          validation_split=.10,
          verbose=True)
# Out:
# 2/2 [==============================] - 1s 257ms/step - loss: 6.8786 - val_loss: 5.3041

# %% [markdown]
# ### Evaluate the model on a test set

# %%
# Evaluate the model on the test data
model.evaluate(X_test, y_test)
# Out:
# 3/3 [==============================] - 0s 8ms/step - loss: 7.6246
# 7.624619483947754

# %% [markdown]
# ## Multiple Outputs

# %% [markdown]
# ### Simple two-output model

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(50, input_shape=(2,), name='dense1'))
model.add(Dense(30, name='dense2'))
model.add(Dense(2, name='output'))
model.compile(optimizer='adam', loss='binary_crossentropy')
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense1 (Dense)              (None, 50)                150
#
#  dense2 (Dense)              (None, 30)                1530
#
#  output (Dense)              (None, 2)                 62
#
# =================================================================
# Total params: 1742 (6.80 KB)
# Trainable params: 1742 (6.80 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Fit a model with two outputs

# %%
# Fit the model
X_train, X_test, y_train, y_test = train_test_split(df[['age', 'sex']], df[['target','thal']])
model.fit(X_train, y_train,
  		  verbose=False,
  		  epochs=10,
  		  batch_size=64)

# %%
# Evaluate the model
model.evaluate(X_test, y_test)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss
#        [-5.8124602e-02,  2.3147464e-04],
#        [ 3.2528695e-01,  9.1537029e-02],
#        [-4.8710495e-02, -3.8425708e-01],
#        [-3.1998229e-01,  2.9244253e-01],
#        [-3.9922023e-01, -2.1259527e-01],
#        [-2.0646292e-01,  3.7929371e-01],
#        [ 2.3495287e-02,  3.8724729e-01],
#        [ 2.8323069e-01, -1.5894860e-02],
#        [ 2.0493355e-01,  4.1538537e-02]], dtype=float32), array([0., 0.], dtype=float32)]

# %% [markdown]
# ### Classification and regression in one model

# %%
# Create an input layer with 2 columns
input_tensor = Input((2,))
# Create the first output
output_tensor_1 = Dense(1, activation='linear', use_bias=False)(input_tensor)

# Create the second output (use the first output as input here)
output_tensor_2 = Dense(1, activation='sigmoid', use_bias=False)(output_tensor_1)

# Create a model with 2 outputs
model = Model(input_tensor, [output_tensor_1, output_tensor_2])

# %% [markdown]
# ### Compile and fit the model

# %%
# Import the Adam optimizer
from keras.optimizers import Adam

# Compile the model with 2 losses and the Adam optimzer with a higher learning rate
model.compile(loss=['mean_absolute_error', 'binary_crossentropy'], optimizer=Adam(lr=0.01))

# Fit the model to the training data, with 2 inputs and 2 outputs
model.fit(df[['age', 'sex']],
          [df[['chol']], df[['target']]],
          epochs=10,
          verbose=True,
          batch_size=16384)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/10
# 1/1 [==============================] - 2s 2s/step - loss: 248.3463 - dense_loss: 247.5064 - dense_1_loss: 0.8399
# Epoch 2/10
# 1/1 [==============================] - 0s 27ms/step - loss: 248.2813 - dense_loss: 247.4513 - dense_1_loss: 0.8299
# Epoch 3/10
# 1/1 [==============================] - 0s 15ms/step - loss: 248.2168 - dense_loss: 247.3963 - dense_1_loss: 0.8205
# Epoch 4/10
# 1/1 [==============================] - 0s 37ms/step - loss: 248.1528 - dense_loss: 247.3413 - dense_1_loss: 0.8115
# Epoch 5/10
# 1/1 [==============================] - 0s 32ms/step - loss: 248.0893 - dense_loss: 247.2863 - dense_1_loss: 0.8030
# Epoch 6/10
# 1/1 [==============================] - 0s 26ms/step - loss: 248.0264 - dense_loss: 247.2314 - dense_1_loss: 0.7950
# Epoch 7/10
# 1/1 [==============================] - 0s 36ms/step - loss: 247.9639 - dense_loss: 247.1764 - dense_1_loss: 0.7875
# Epoch 8/10
# 1/1 [==============================] - 0s 29ms/step - loss: 247.9021 - dense_loss: 247.1216 - dense_1_loss: 0.7805
# Epoch 9/10
# 1/1 [==============================] - 0s 42ms/step - loss: 247.8407 - dense_loss: 247.0667 - dense_1_loss: 0.7740
# Epoch 10/10
# 1/1 [==============================] - 0s 24ms/step - loss: 247.7799 - dense_loss: 247.0119 - dense_1_loss: 0.7680

# %% [markdown]
# ### Inspect the model (II)

# %%
# Print the model weights
print(model.get_weights())
# Out:
# [array([[-0.00311579],
#        [-0.766797  ]], dtype=float32), array([[-0.82919747]], dtype=float32)]

# %% [markdown]
# # Keras Model with all Columns

# %%
# https://keras.io/api/models/sequential/
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

df = pd.read_csv('heart_disease_dataset_UCI.csv')
X = df.iloc[:,0:13]
y = df.iloc[:,13]
X = X.values
y = y.values
from sklearn.preprocessing import StandardScaler
X_std=StandardScaler().fit_transform(X)
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_std,y,test_size=0.25,random_state=40)

# define the keras model
model = Sequential()
model.add(Dense(12, input_shape=(13,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(X_train, y_train, epochs=100, batch_size=100)
# evaluate the keras model
_,accuracy = model.evaluate(X_test, y_test)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/100
# 3/3 [==============================] - 1s 6ms/step - loss: 0.7015 - accuracy: 0.5066
# Epoch 2/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6919 - accuracy: 0.5198
# Epoch 3/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6825 - accuracy: 0.5374
# Epoch 4/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6744 - accuracy: 0.5683
# Epoch 5/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6659 - accuracy: 0.5771
# Epoch 6/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6579 - accuracy: 0.5947
# Epoch 7/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6505 - accuracy: 0.5947
# Epoch 8/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6428 - accuracy: 0.6035
# Epoch 9/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6359 - accuracy: 0.6211
# Epoch 10/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6287 - accuracy: 0.6256
# Epoch 11/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6219 - accuracy: 0.6476
# Epoch 12/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6151 - accuracy: 0.6740
# Epoch 13/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6086 - accuracy: 0.6828
# Epoch 14/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6021 - accuracy: 0.6828
# Epoch 15/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5958 - accuracy: 0.6960
# Epoch 16/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5896 - accuracy: 0.7004
# Epoch 17/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5832 - accuracy: 0.7093
# Epoch 18/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.5769 - accuracy: 0.7181
# Epoch 19/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5707 - accuracy: 0.7181
# Epoch 20/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5641 - accuracy: 0.7225
# Epoch 21/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5581 - accuracy: 0.7269
# Epoch 22/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5520 - accuracy: 0.7269
# Epoch 23/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.5459 - accuracy: 0.7269
# Epoch 24/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5399 - accuracy: 0.7313
# Epoch 25/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.5340 - accuracy: 0.7401
# Epoch 26/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.5282 - accuracy: 0.7401
# Epoch 27/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.5221 - accuracy: 0.7401
# Epoch 28/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5167 - accuracy: 0.7401
# Epoch 29/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.5111 - accuracy: 0.7445
# Epoch 30/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5053 - accuracy: 0.7533
# Epoch 31/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5002 - accuracy: 0.7533
# Epoch 32/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.4946 - accuracy: 0.7621
# Epoch 33/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4891 - accuracy: 0.7797
# Epoch 34/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4834 - accuracy: 0.7797
# Epoch 35/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4778 - accuracy: 0.7753
# Epoch 36/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4723 - accuracy: 0.7797
# Epoch 37/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4671 - accuracy: 0.7841
# Epoch 38/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4619 - accuracy: 0.7930
# Epoch 39/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4566 - accuracy: 0.7930
# Epoch 40/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4519 - accuracy: 0.8018
# Epoch 41/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4471 - accuracy: 0.8106
# Epoch 42/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4423 - accuracy: 0.8106
# Epoch 43/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.4376 - accuracy: 0.8150
# Epoch 44/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4335 - accuracy: 0.8150
# Epoch 45/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.4293 - accuracy: 0.8150
# Epoch 46/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4252 - accuracy: 0.8150
# Epoch 47/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4212 - accuracy: 0.8150
# Epoch 48/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4175 - accuracy: 0.8194
# Epoch 49/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4139 - accuracy: 0.8238
# Epoch 50/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4104 - accuracy: 0.8238
# Epoch 51/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4071 - accuracy: 0.8238
# Epoch 52/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4038 - accuracy: 0.8238
# Epoch 53/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4006 - accuracy: 0.8238
# Epoch 54/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3974 - accuracy: 0.8238
# Epoch 55/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3947 - accuracy: 0.8238
# Epoch 56/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3917 - accuracy: 0.8238
# Epoch 57/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3889 - accuracy: 0.8282
# Epoch 58/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3863 - accuracy: 0.8282
# Epoch 59/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3837 - accuracy: 0.8326
# Epoch 60/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3812 - accuracy: 0.8370
# Epoch 61/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3788 - accuracy: 0.8370
# Epoch 62/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3765 - accuracy: 0.8370
# Epoch 63/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3742 - accuracy: 0.8414
# Epoch 64/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3721 - accuracy: 0.8414
# Epoch 65/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3696 - accuracy: 0.8414
# Epoch 66/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3676 - accuracy: 0.8414
# Epoch 67/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3655 - accuracy: 0.8326
# Epoch 68/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3633 - accuracy: 0.8326
# Epoch 69/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3613 - accuracy: 0.8282
# Epoch 70/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3594 - accuracy: 0.8326
# Epoch 71/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3576 - accuracy: 0.8326
# Epoch 72/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3557 - accuracy: 0.8326
# Epoch 73/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3540 - accuracy: 0.8282
# Epoch 74/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3521 - accuracy: 0.8282
# Epoch 75/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3503 - accuracy: 0.8282
# Epoch 76/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3485 - accuracy: 0.8326
# Epoch 77/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3467 - accuracy: 0.8326
# Epoch 78/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3449 - accuracy: 0.8326
# Epoch 79/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3433 - accuracy: 0.8282
# Epoch 80/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3416 - accuracy: 0.8282
# Epoch 81/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3401 - accuracy: 0.8370
# Epoch 82/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3384 - accuracy: 0.8370
# Epoch 83/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3370 - accuracy: 0.8370
# Epoch 84/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3355 - accuracy: 0.8370
# Epoch 85/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3339 - accuracy: 0.8370
# Epoch 86/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3325 - accuracy: 0.8370
# Epoch 87/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3311 - accuracy: 0.8414
# Epoch 88/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3296 - accuracy: 0.8502
# Epoch 89/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3282 - accuracy: 0.8502
# Epoch 90/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3268 - accuracy: 0.8502
# Epoch 91/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3254 - accuracy: 0.8502
# Epoch 92/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3242 - accuracy: 0.8546
# Epoch 93/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3229 - accuracy: 0.8546
# Epoch 94/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3215 - accuracy: 0.8546
# Epoch 95/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3203 - accuracy: 0.8546
# Epoch 96/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3190 - accuracy: 0.8546
# Epoch 97/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3177 - accuracy: 0.8546
# Epoch 98/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3166 - accuracy: 0.8546
# Epoch 99/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3153 - accuracy: 0.8546
# Epoch 100/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3142 - accuracy: 0.8546
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3215 - accuracy: 0.8684
# Accuracy: 86.84

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 12)                168
#
#  dense_3 (Dense)             (None, 8)                 104
#
#  dense_4 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 281 (1.10 KB)
# Trainable params: 281 (1.10 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #Effect of Batch Size

# %%
# https://keras.io/api/models/sequential/
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

df = pd.read_csv('heart_disease_dataset_UCI.csv')
X = df.iloc[:,0:13]
y = df.iloc[:,13]
X = X.values
y = y.values
from sklearn.preprocessing import StandardScaler
X_std=StandardScaler().fit_transform(X)
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_std,y,test_size=0.25,random_state=40)

# %%
from time import time
batch_sizes = [10,50,100, 150,200,250]
plt.figure(figsize=(16,15))
for i in range(len(batch_sizes)):

  print('\n Batch Size'+str(batch_sizes[i]))
  start=time()

  # define the keras model
  model = Sequential()
  model.add(Dense(12, input_shape=(13,), activation='relu'))
  model.add(Dense(8, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))
  # compile the keras model
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
  history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, verbose=1, batch_size=batch_sizes[i])

  plot_no = 420 + (i+1)

  plt.subplot(plot_no)
  plt.plot(history.history['accuracy'], label='train')
  plt.plot(history.history['val_accuracy'], label='test')
  plt.title('batch='+str(batch_sizes[i])+'Time:'+str(time()-start))
# show learning curves
plt.show()
# Out:
#  Batch Size10
# Epoch 1/100
# 23/23 [==============================] - 1s 11ms/step - loss: 0.6648 - accuracy: 0.6564 - val_loss: 0.6359 - val_accuracy: 0.7237
# Epoch 2/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.
100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3238 - accuracy: 0.8767 - val_loss: 0.3145 - val_accuracy: 0.8289
# Epoch 35/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3203 - accuracy: 0.8767 - val_loss: 0.3162 - val_accuracy: 0.8289
# Epoch 36/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3160 - accuracy: 0.8811 - val_loss: 0.3176 - val_accuracy: 0.8553
# Epoch 37/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3132 - accuracy: 0.8811 - val_loss: 0.3215 - val_accuracy: 0.8421
# Epoch 38/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.3101 - accuracy: 0.8767 - val_loss: 0.3206 - val_accuracy: 0.8421
# Epoch 39/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3063 - accuracy: 0.8767 - val_loss: 0.3238 - val_accuracy: 0.8421
# Epoch 40/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3023 - accuracy: 0.8811 - val_loss: 0.3239 - val_accuracy: 0.8421
# Epoch 41/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2995 - accuracy: 0.8811 - val_loss: 0.3253 - val_accuracy: 0.8553
# Epoch 42/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2954 - accuracy: 0.8811 - val_loss: 0.3302 - val_accuracy: 0.8421
# Epoch 43/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.2944 - accuracy: 0.8855 - val_loss: 0.3294 - val_accuracy: 0.8553
# Epoch 44/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2905 - accuracy: 0.8811 - val_loss: 0.3361 - val_accuracy: 0.8421
# Epoch 45/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2861 - accuracy: 0.8855 - val_loss: 0.3383 - val_accuracy: 0.8421
# Epoch 46/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.2844 - accuracy: 0.8855 - val_loss: 0.3402 - val_accuracy: 0.8553
# Epoch 47/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.2819 - accuracy: 0.8899 - val_loss: 0.3399 - val_accuracy: 0.8421
# Epoch 48/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.2784 - accuracy: 0.8855 - val_loss: 0.3447 - val_accuracy: 0.8421
# Epoch 49/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.2762 - accuracy: 0.8855 - val_loss: 0.3482 - val_accuracy: 0.8421
# Epoch 50/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2739 - accuracy: 0.8943 - val_loss: 0.3519 - val_accuracy: 0.8289
# Epoch 51/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2708 - accuracy: 0.8943 - val_loss: 0.3553 - val_accuracy: 0.8421
# Epoch 52/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2681 - accuracy: 0.8943 - val_loss: 0.3570 - val_accuracy: 0.8421
# Epoch 53/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2667 - accuracy: 0.8943 - val_loss: 0.3582 - val_accuracy: 0.8421
# Epoch 54/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2633 - accuracy: 0.8943 - val_loss: 0.3620 - val_accuracy: 0.8421
# Epoch 55/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2612 - accuracy: 0.8943 - val_loss: 0.3672 - val_accuracy: 0.8421
# Epoch 56/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2590 - accuracy: 0.9031 - val_loss: 0.3691 - val_accuracy: 0.8421
# Epoch 57/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2562 - accuracy: 0.9075 - val_loss: 0.3717 - val_accuracy: 0.8421
# Epoch 58/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2546 - accuracy: 0.9075 - val_loss: 0.3724 - val_accuracy: 0.8421
# Epoch 59/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2524 - accuracy: 0.9119 - val_loss: 0.3768 - val_accuracy: 0.8289
# Epoch 60/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2496 - accuracy: 0.9075 - val_loss: 0.3820 - val_accuracy: 0.8289
# Epoch 61/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2479 - accuracy: 0.9119 - val_loss: 0.3835 - val_accuracy: 0.8421
# Epoch 62/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2459 - accuracy: 0.9119 - val_loss: 0.3886 - val_accuracy: 0.8421
# Epoch 63/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2435 - accuracy: 0.9163 - val_loss: 0.3921 - val_accuracy: 0.8289
# Epoch 64/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2428 - accuracy: 0.9119 - val_loss: 0.3906 - val_accuracy: 0.8421
# Epoch 65/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2399 - accuracy: 0.9119 - val_loss: 0.3975 - val_accuracy: 0.8421
# Epoch 66/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.
100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3487 - accuracy: 0.8767 - val_loss: 0.3448 - val_accuracy: 0.9079
# Epoch 91/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3466 - accuracy: 0.8767 - val_loss: 0.3438 - val_accuracy: 0.9079
# Epoch 92/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3442 - accuracy: 0.8767 - val_loss: 0.3433 - val_accuracy: 0.9079
# Epoch 93/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3422 - accuracy: 0.8767 - val_loss: 0.3427 - val_accuracy: 0.9079
# Epoch 94/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3401 - accuracy: 0.8811 - val_loss: 0.3425 - val_accuracy: 0.9079
# Epoch 95/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3383 - accuracy: 0.8811 - val_loss: 0.3422 - val_accuracy: 0.9079
# Epoch 96/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3362 - accuracy: 0.8811 - val_loss: 0.3423 - val_accuracy: 0.9079
# Epoch 97/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3344 - accuracy: 0.8811 - val_loss: 0.3419 - val_accuracy: 0.9079
# Epoch 98/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3323 - accuracy: 0.8811 - val_loss: 0.3417 - val_accuracy: 0.9079
# Epoch 99/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3307 - accuracy: 0.8811 - val_loss: 0.3420 - val_accuracy: 0.9079
# Epoch 100/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3287 - accuracy: 0.8811 - val_loss: 0.3425 - val_accuracy: 0.9079
#
#  Batch Size100
# Epoch 1/100
# 3/3 [==============================] - 1s 106ms/step - loss: 0.7105 - accuracy: 0.5683 - val_loss: 0.6464 - val_accuracy: 0.5921
# Epoch 2/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6971 - accuracy: 0.5991 - val_loss: 0.6357 - val_accuracy: 0.6053
# Epoch 3/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6849 - accuracy: 0.6167 - val_loss: 0.6258 - val_accuracy: 0.5921
# Epoch 4/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6730 - accuracy: 0.6344 - val_loss: 0.6163 - val_accuracy: 0.6184
# Epoch 5/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6632 - accuracy: 0.6344 - val_loss: 0.6071 - val_accuracy: 0.6316
# Epoch 6/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6530 - accuracy: 0.6476 - val_loss: 0.5989 - val_accuracy: 0.6579
# Epoch 7/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6439 - accuracy: 0.6696 - val_loss: 0.5913 - val_accuracy: 0.6842
# Epoch 8/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6352 - accuracy: 0.6784 - val_loss: 0.5841 - val_accuracy: 0.6842
# Epoch 9/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6274 - accuracy: 0.6828 - val_loss: 0.5774 - val_accuracy: 0.6842
# Epoch 10/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6196 - accuracy: 0.6916 - val_loss: 0.5709 - val_accuracy: 0.7105
# Epoch 11/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.6119 - accuracy: 0.7004 - val_loss: 0.5648 - val_accuracy: 0.7368
# Epoch 12/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6048 - accuracy: 0.7093 - val_loss: 0.5588 - val_accuracy: 0.7237
# Epoch 13/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.5979 - accuracy: 0.7137 - val_loss: 0.5530 - val_accuracy: 0.7500
# Epoch 14/100
# 3/3 [==============================] - 0s 28ms/step - loss: 0.5907 - accuracy: 0.7181 - val_loss: 0.5472 - val_accuracy: 0.7500
# Epoch 15/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.5841 - accuracy: 0.7269 - val_loss: 0.5415 - val_accuracy: 0.7763
# Epoch 16/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.5781 - accuracy: 0.7357 - val_loss: 0.5357 - val_accuracy: 0.7763
# Epoch 17/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.5714 - accuracy: 0.7445 - val_loss: 0.5300 - val_accuracy: 0.7763
# Epoch 18/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.5654 - accuracy: 0.7489 - val_loss: 0.5242 - val_accuracy: 0.7763
# Epoch 19/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.5591 - accuracy: 0.7533 - val_loss: 0.5185 - val_accuracy: 0.7763
# Epoch 20/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.5534 - accuracy: 0.7489 - val_loss: 0.5126 - val_accuracy: 0.7895
# Epoch 21/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.
100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3629 - accuracy: 0.8370 - val_loss: 0.2962 - val_accuracy: 0.9211
# Epoch 86/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3614 - accuracy: 0.8370 - val_loss: 0.2955 - val_accuracy: 0.9211
# Epoch 87/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3600 - accuracy: 0.8370 - val_loss: 0.2951 - val_accuracy: 0.9211
# Epoch 88/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3587 - accuracy: 0.8370 - val_loss: 0.2945 - val_accuracy: 0.9211
# Epoch 89/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3570 - accuracy: 0.8370 - val_loss: 0.2942 - val_accuracy: 0.9211
# Epoch 90/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3558 - accuracy: 0.8414 - val_loss: 0.2937 - val_accuracy: 0.9211
# Epoch 91/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3542 - accuracy: 0.8414 - val_loss: 0.2935 - val_accuracy: 0.9211
# Epoch 92/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3529 - accuracy: 0.8458 - val_loss: 0.2936 - val_accuracy: 0.9211
# Epoch 93/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3516 - accuracy: 0.8458 - val_loss: 0.2936 - val_accuracy: 0.9079
# Epoch 94/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3503 - accuracy: 0.8546 - val_loss: 0.2936 - val_accuracy: 0.9079
# Epoch 95/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3490 - accuracy: 0.8546 - val_loss: 0.2936 - val_accuracy: 0.9079
# Epoch 96/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3477 - accuracy: 0.8546 - val_loss: 0.2937 - val_accuracy: 0.9079
# Epoch 97/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.3463 - accuracy: 0.8590 - val_loss: 0.2935 - val_accuracy: 0.9079
# Epoch 98/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3452 - accuracy: 0.8590 - val_loss: 0.2933 - val_accuracy: 0.9079
# Epoch 99/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3440 - accuracy: 0.8590 - val_loss: 0.2932 - val_accuracy: 0.9079
# Epoch 100/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3428 - accuracy: 0.8590 - val_loss: 0.2931 - val_accuracy: 0.9079
#
#  Batch Size150
# Epoch 1/100
# 2/2 [==============================] - 1s 237ms/step - loss: 0.7037 - accuracy: 0.5639 - val_loss: 0.7349 - val_accuracy: 0.5000
# Epoch 2/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6929 - accuracy: 0.5815 - val_loss: 0.7232 - val_accuracy: 0.5000
# Epoch 3/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6831 - accuracy: 0.5859 - val_loss: 0.7125 - val_accuracy: 0.5132
# Epoch 4/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6735 - accuracy: 0.5947 - val_loss: 0.7023 - val_accuracy: 0.5263
# Epoch 5/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6643 - accuracy: 0.6035 - val_loss: 0.6922 - val_accuracy: 0.5526
# Epoch 6/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6558 - accuracy: 0.6344 - val_loss: 0.6827 - val_accuracy: 0.5789
# Epoch 7/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6470 - accuracy: 0.6388 - val_loss: 0.6739 - val_accuracy: 0.5921
# Epoch 8/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.6393 - accuracy: 0.6476 - val_loss: 0.6652 - val_accuracy: 0.6316
# Epoch 9/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6313 - accuracy: 0.6608 - val_loss: 0.6568 - val_accuracy: 0.6447
# Epoch 10/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6243 - accuracy: 0.6784 - val_loss: 0.6487 - val_accuracy: 0.6579
# Epoch 11/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.6172 - accuracy: 0.6916 - val_loss: 0.6408 - val_accuracy: 0.6974
# Epoch 12/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6103 - accuracy: 0.6916 - val_loss: 0.6331 - val_accuracy: 0.7105
# Epoch 13/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6040 - accuracy: 0.6960 - val_loss: 0.6256 - val_accuracy: 0.7237
# Epoch 14/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5977 - accuracy: 0.7048 - val_loss: 0.6185 - val_accuracy: 0.7237
# Epoch 15/100
# 2/2 [==============================] - 0s 77ms/step - loss: 0.5918 - accuracy: 0.7137 - val_loss: 0.6115 - val_accuracy: 0.7237
# Epoch 16/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.5859 - accuracy: 0.7269 - val_loss: 0.6050 - val_accuracy: 0.7237
# Epoch 17/100
# 2/2 [==============================] - 0s 85ms/step - loss: 0.5804 - accuracy: 0.7357 - val_loss: 0.5987 - val_accuracy: 0.7368
# Epoch 18/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5748 - accuracy: 0.7401 - val_loss: 0.5925 - val_accuracy: 0.7368
# Epoch 19/100
# 2/2 [==============================] - 0s 91ms/step - loss: 0.5695 - accuracy: 0.7489 - val_loss: 0.5864 - val_accuracy: 0.7368
# Epoch 20/100
# 2/2 [==============================] - 0s 79ms/step - loss: 0.5647 - accuracy: 0.7533 - val_loss: 0.5803 - val_accuracy: 0.7763
# Epoch 21/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.5593 - accuracy: 0.7621 - val_loss: 0.5744 - val_accuracy: 0.8026
# Epoch 22/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.5546 - accuracy: 0.7665 - val_loss: 0.5686 - val_accuracy: 0.8026
# Epoch 23/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5499 - accuracy: 0.7621 - val_loss: 0.5630 - val_accuracy: 0.8026
# Epoch 24/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5451 - accuracy: 0.7665 - val_loss: 0.5576 - val_accuracy: 0.8026
# Epoch 25/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5406 - accuracy: 0.7665 - val_loss: 0.5522 - val_accuracy: 0.8158
# Epoch 26/100
# 2/2 [==============================] - 0s 74ms/step - loss: 0.5361 - accuracy: 0.7753 - val_loss: 0.5469 - val_accuracy: 0.8158
# Epoch 27/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.5318 - accuracy: 0.7841 - val_loss: 0.5418 - val_accuracy: 0.8158
# Epoch 28/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5274 - accuracy: 0.7885 - val_loss: 0.5366 - val_accuracy: 0.8158
# Epoch 29/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5233 - accuracy: 0.7885 - val_loss: 0.5315 - val_accuracy: 0.8158
# Epoch 30/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.5190 - accuracy: 0.7930 - val_loss: 0.5265 - val_accuracy: 0.8158
# Epoch 31/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.5152 - accuracy: 0.7930 - val_loss: 0.5214 - val_accuracy: 0.8289
# Epoch 32/100
# 2/2 [==============================] - 0s 82ms/step - loss: 0.5111 - accuracy: 0.7930 - val_loss: 0.5166 - val_accuracy: 0.8289
# Epoch 33/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.5072 - accuracy: 0.7930 - val_loss: 0.5117 - val_accuracy: 0.8289
# Epoch 34/100
# 2/2 [==============================] - 0s 77ms/step - loss: 0.5032 - accuracy: 0.7930 - val_loss: 0.5070 - val_accuracy: 0.8289
# Epoch 35/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.4995 - accuracy: 0.7930 - val_loss: 0.5021 - val_accuracy: 0.8289
# Epoch 36/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4957 - accuracy: 0.7930 - val_loss: 0.4975 - val_accuracy: 0.8289
# Epoch 37/100
# 2/2 [==============================] - 0s 86ms/step - loss: 0.4920 - accuracy: 0.7930 - val_loss: 0.4930 - val_accuracy: 0.8289
# Epoch 38/100
# 2/2 [==============================] - 0s 85ms/step - loss: 0.4883 - accuracy: 0.7930 - val_loss: 0.4886 - val_accuracy: 0.8289
# Epoch 39/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.4847 - accuracy: 0.7974 - val_loss: 0.4843 - val_accuracy: 0.8289
# Epoch 40/100
# ...
# Epoch 88/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.4080 - accuracy: 0.8326 - val_loss: 0.3128 - val_accuracy: 0.8816
# Epoch 89/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.4065 - accuracy: 0.8326 - val_loss: 0.3110 - val_accuracy: 0.8816
# Epoch 90/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.4049 - accuracy: 0.8326 - val_loss: 0.3093 - val_accuracy: 0.8816
# Epoch 91/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.4035 - accuracy: 0.8326 - val_loss: 0.3079 - val_accuracy: 0.8816
# Epoch 92/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.4021 - accuracy: 0.8282 - val_loss: 0.3065 - val_accuracy: 0.8947
# Epoch 93/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.4007 - accuracy: 0.8326 - val_loss: 0.3050 - val_accuracy: 0.8947
# Epoch 94/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.3994 - accuracy: 0.8326 - val_loss: 0.3035 - val_accuracy: 0.8816
# Epoch 95/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3980 - accuracy: 0.8326 - val_loss: 0.3019 - val_accuracy: 0.8816
# Epoch 96/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.3969 - accuracy: 0.8326 - val_loss: 0.3004 - val_accuracy: 0.8816
# Epoch 97/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3956 - accuracy: 0.8326 - val_loss: 0.2990 - val_accuracy: 0.8947
# Epoch 98/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.3943 - accuracy: 0.8326 - val_loss: 0.2976 - val_accuracy: 0.8947
# Epoch 99/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3932 - accuracy: 0.8370 - val_loss: 0.2963 - val_accuracy: 0.8947
# Epoch 100/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.3921 - accuracy: 0.8370 - val_loss: 0.2949 - val_accuracy: 0.8947
#
#  Batch Size250
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.7252 - accuracy: 0.4934 - val_loss: 0.7649 - val_accuracy: 0.4079
# Epoch 2/100
# 1/1 [==============================] - 0s 74ms/step - loss: 0.7207 - accuracy: 0.4978 - val_loss: 0.7600 - val_accuracy: 0.4079
# Epoch 3/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.7164 - accuracy: 0.4978 - val_loss: 0.7553 - val_accuracy: 0.4211
# Epoch 4/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.7122 - accuracy: 0.5066 - val_loss: 0.7507 - val_accuracy: 0.4211
# Epoch 5/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.7082 - accuracy: 0.5066 - val_loss: 0.7461 - val_accuracy: 0.4342
# Epoch 6/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.7043 - accuracy: 0.5110 - val_loss: 0.7416 - val_accuracy: 0.4342
# Epoch 7/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.7006 - accuracy: 0.5110 - val_loss: 0.7372 - val_accuracy: 0.4342
# Epoch 8/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.6970 - accuracy: 0.5110 - val_loss: 0.7330 - val_accuracy: 0.4342
# Epoch 9/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.6936 - accuracy: 0.5198 - val_loss: 0.7288 - val_accuracy: 0.4474
# Epoch 10/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.6903 - accuracy: 0.5286 - val_loss: 0.7247 - val_accuracy: 0.4342
# Epoch 11/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6871 - accuracy: 0.5330 - val_loss: 0.7207 - val_accuracy: 0.4474
# Epoch 12/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.6841 - accuracy: 0.5419 - val_loss: 0.7168 - val_accuracy: 0.4474
# Epoch 13/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.6810 - accuracy: 0.5463 - val_loss: 0.7131 - val_accuracy: 0.4605
# Epoch 14/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.6781 - accuracy: 0.5551 - val_loss: 0.7095 - val_accuracy: 0.4737
# Epoch 15/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.6753 - accuracy: 0.5727 - val_loss: 0.7060 - val_accuracy: 0.4737
# Epoch 16/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6724 - accuracy: 0.5815 - val_loss: 0.7025 - val_accuracy: 0.5000
# Epoch 17/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.6697 - accuracy: 0.5903 - val_loss: 0.6990 - val_accuracy: 0.5132
# Epoch 18/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.6670 - accuracy: 0.5991 - val_loss: 0.6956 - val_accuracy: 0.5526
# Epoch 19/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.6644 - accuracy: 0.6035 - val_loss: 0.6924 - val_accuracy: 0.5526
# Epoch 20/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.6618 - accuracy: 0.6035 - val_loss: 0.6892 - val_accuracy: 0.5658
# Epoch 21/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6593 - accuracy: 0.6123 - val_loss: 0.6860 - val_accuracy: 0.5789
# Epoch 22/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.6569 - accuracy: 0.6123 - val_loss: 0.6829 - val_accuracy: 0.5789
# Epoch 23/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.6544 - accuracy: 0.6123 - val_loss: 0.6798 - val_accuracy: 0.5789
# Epoch 24/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6520 - accuracy: 0.6167 - val_loss: 0.6768 - val_accuracy: 0.5789
# Epoch 25/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.6497 - accuracy: 0.6211 - val_loss: 0.6737 - val_accuracy: 0.5921
# Epoch 26/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.
100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5791 - accuracy: 0.7137 - val_loss: 0.5736 - val_accuracy: 0.7105
# Epoch 58/100
# 1/1 [==============================] - 0s 74ms/step - loss: 0.5769 - accuracy: 0.7137 - val_loss: 0.5703 - val_accuracy: 0.7105
# Epoch 59/100
# 1/1 [==============================] - 0s 73ms/step - loss: 0.5747 - accuracy: 0.7137 - val_loss: 0.5669 - val_accuracy: 0.7105
# Epoch 60/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.5725 - accuracy: 0.7225 - val_loss: 0.5636 - val_accuracy: 0.7105
# Epoch 61/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.5702 - accuracy: 0.7269 - val_loss: 0.5603 - val_accuracy: 0.7105
# Epoch 62/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.5680 - accuracy: 0.7313 - val_loss: 0.5571 - val_accuracy: 0.7105
# Epoch 63/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5658 - accuracy: 0.7357 - val_loss: 0.5539 - val_accuracy: 0.7105
# Epoch 64/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5635 - accuracy: 0.7401 - val_loss: 0.5507 - val_accuracy: 0.7105
# Epoch 65/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.5613 - accuracy: 0.7401 - val_loss: 0.5475 - val_accuracy: 0.7105
# Epoch 66/100
# 1/1 [==============================] - 0s 71ms/step - loss: 0.5590 - accuracy: 0.7445 - val_loss: 0.5444 - val_accuracy: 0.7237
# Epoch 67/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5567 - accuracy: 0.7445 - val_loss: 0.5413 - val_accuracy: 0.7237
# Epoch 68/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5544 - accuracy: 0.7445 - val_loss: 0.5382 - val_accuracy: 0.7237
# Epoch 69/100
# 1/1 [==============================] - 0s 82ms/step - loss: 0.5521 - accuracy: 0.7445 - val_loss: 0.5352 - val_accuracy: 0.7237
# Epoch 70/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5499 - accuracy: 0.7445 - val_loss: 0.5321 - val_accuracy: 0.7237
# Epoch 71/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5476 - accuracy: 0.7445 - val_loss: 0.5291 - val_accuracy: 0.7237
# Epoch 72/100
# 1/1 [==============================] - 0s 78ms/step - loss: 0.5454 - accuracy: 0.7445 - val_loss: 0.5260 - val_accuracy: 0.7237
# Epoch 73/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.5431 - accuracy: 0.7489 - val_loss: 0.5230 - val_accuracy: 0.7237
# Epoch 74/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.5409 - accuracy: 0.7489 - val_loss: 0.5200 - val_accuracy: 0.7237
# Epoch 75/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.5386 - accuracy: 0.7489 - val_loss: 0.5170 - val_accuracy: 0.7237
# Epoch 76/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5364 - accuracy: 0.7533 - val_loss: 0.5140 - val_accuracy: 0.7237
# Epoch 77/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5341 - accuracy: 0.7577 - val_loss: 0.5110 - val_accuracy: 0.7237
# Epoch 78/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.5319 - accuracy: 0.7577 - val_loss: 0.5081 - val_accuracy: 0.7105
# Epoch 79/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.5297 - accuracy: 0.7577 - val_loss: 0.5052 - val_accuracy: 0.6974
# Epoch 80/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.5275 - accuracy: 0.7577 - val_loss: 0.5023 - val_accuracy: 0.6974
# Epoch 81/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.5253 - accuracy: 0.7621 - val_loss: 0.4994 - val_accuracy: 0.6974
# Epoch 82/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.5232 - accuracy: 0.7621 - val_loss: 0.4966 - val_accuracy: 0.7105
# Epoch 83/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.5210 - accuracy: 0.7621 - val_loss: 0.4938 - val_accuracy: 0.7105
# Epoch 84/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5189 - accuracy: 0.7621 - val_loss: 0.4911 - val_accuracy: 0.7105
# Epoch 85/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.5167 - accuracy: 0.7621 - val_loss: 0.4882 - val_accuracy: 0.7105
# Epoch 86/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5145 - accuracy: 0.7621 - val_loss: 0.4854 - val_accuracy: 0.7105
# Epoch 87/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.5123 - accuracy: 0.7621 - val_loss: 0.4827 - val_accuracy: 0.7105
# Epoch 88/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.5102 - accuracy: 0.7665 - val_loss: 0.4799 - val_accuracy: 0.7105
# Epoch 89/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.5080 - accuracy: 0.7665 - val_loss: 0.4773 - val_accuracy: 0.7105
# Epoch 90/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.5059 - accuracy: 0.7753 - val_loss: 0.4746 - val_accuracy: 0.7237
# Epoch 91/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.5038 - accuracy: 0.7753 - val_loss: 0.4720 - val_accuracy: 0.7237
# Epoch 92/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.5017 - accuracy: 0.7841 - val_loss: 0.4694 - val_accuracy: 0.7237
# Epoch 93/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4996 - accuracy: 0.7841 - val_loss: 0.4668 - val_accuracy: 0.7237
# Epoch 94/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4974 - accuracy: 0.7885 - val_loss: 0.4642 - val_accuracy: 0.7368
# Epoch 95/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4953 - accuracy: 0.7885 - val_loss: 0.4617 - val_accuracy: 0.7368
# Epoch 96/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4933 - accuracy: 0.7885 - val_loss: 0.4593 - val_accuracy: 0.7368
# Epoch 97/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4912 - accuracy: 0.7885 - val_loss: 0.4569 - val_accuracy: 0.7368
# Epoch 98/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4891 - accuracy: 0.7974 - val_loss: 0.4545 - val_accuracy: 0.7368
# Epoch 99/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4871 - accuracy: 0.7930 - val_loss: 0.4522 - val_accuracy: 0.7368
# Epoch 100/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4850 - accuracy: 0.7930 - val_loss: 0.4499 - val_accuracy: 0.7368

# %% [markdown]
# #References
# * https://machinelearningmastery.com/tutorial-first-neural-network-python-keras/
# * https://github.com/ozlerhakan/datacamp/blob/master/Advanced%20Deep%20Learning%20with%20Keras%20in%20Python/Advanced-Deep-Learning-with-Keras-in-Python.ipynb

# %% [markdown]
# # **Q2**

# %%
from keras import layers, models

mnist =keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0


x_train_flattened = x_train.reshape((x_train.shape[0], -1))
x_test_flattened = x_test.reshape((x_test.shape[0], -1))


model = models.Sequential([
    layers.Dense(5, activation='relu', input_shape=(784,)),
    layers.Dense(5, activation='relu'),
    layers.Dense(5, activation='relu'),
    layers.Dense(5, activation='relu'),
    layers.Dense(5, activation='relu'),
    layers.Dense(10, activation='softmax')
])


model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


history = model.fit(x_train_flattened, y_train, epochs=10, validation_data=(x_test_flattened, y_test))


test_loss, test_acc = model.evaluate(x_test_flattened, y_test)
print('Test accuracy:', test_acc)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 1875/1875 [==============================] - 8s 3ms/step - loss: 1.2704 - accuracy: 0.5480 - val_loss: 0.8370 - val_accuracy: 0.7413
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.7588 - accuracy: 0.7661 - val_loss: 0.7145 - val_accuracy: 0.7816
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6964 - accuracy: 0.7876 - val_loss: 0.6883 - val_accuracy: 0.7890
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6693 - accuracy: 0.7952 - val_loss: 0.6833 - val_accuracy: 0.7964
# Epoch 5/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.6524 - accuracy: 0.8041 - val_loss: 0.6608 - val_accuracy: 0.7991
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6392 - accuracy: 0.8077 - val_loss: 0.6413 - val_accuracy: 0.8086
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.6274 - accuracy: 0.8113 - val_loss: 0.6404 - val_accuracy: 0.8096
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6174 - accuracy: 0.8144 - val_loss: 0.6171 - val_accuracy: 0.8167
# Epoch 9/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.6051 - accuracy: 0.8174 - val_loss: 0.6037 - val_accuracy: 0.8168
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5958 - accuracy: 0.8195 - val_loss: 0.5976 - val_accuracy: 0.8208
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5976 - accuracy: 0.8208
# Test accuracy: 0.8208000063896179
